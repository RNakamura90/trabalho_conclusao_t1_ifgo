# %%
from pathlib import Path
import sys

sys.path.append(str(Path("..").resolve()))

from src.graph_builder import build_campaign_graph
import networkx as nx

# %%
# %store -r receitas_com_originario despesas_pres

# %%
G = build_campaign_graph(
    receitas_com_originario=receitas_com_originario,
    despesas_pres=despesas_pres,
)

G.number_of_nodes(), G.number_of_edges()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 G = build_campaign_graph(
# ----> 2     receitas_com_originario=receitas_com_originario,
#       3     despesas_pres=despesas_pres,
#       4 )
#       6 G.number_of_nodes(), G.number_of_edges()
#
# NameError: name 'receitas_com_originario' is not defined
